# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
url='https://movie.douban.com/'
dom = request.urlopen(url)

# %%
soup = BeautifulSoup(dom, 'html.parser')

# %%
screening_movie = soup.find('div',class_='screening-bd')

# %%
screening_movie
# Out:
# <div class="screening-bd">
# <ul class="ui-slide-content" data-index-max="10" data-slide-index="1">
# <li class="ui-slide-item s" data-actors="安东尼·冈萨雷斯 / 盖尔·加西亚·贝纳尔 / 本杰明·布拉特" data-director="李·昂克里奇" data-dstat-areaid="70_1" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="105分钟" data-enough="true" data-intro="" data-rate="9.1" data-rater="232793" data-region="美国" data-release="2017" data-star="45" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342068%3F_v_%3Dyes%26merCode%3D1000011" data-title="寻梦环游记 Coco" data-trailer="https://movie.douban.com/subject/20495023/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/20495023/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="寻梦环游记" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2503997609.jpg"/>
# </a>
# </li>
# ...

# %%
on_show = screening_movie.find_all('ul',class_='')

# %%
url = on_show[0].find('a',href=True)['href']

# %%
url
# Out:
# 'https://movie.douban.com/subject/20495023/?from=showing'

# %%
dom = request.urlopen(url)
soup = BeautifulSoup(dom, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
#         寻梦环游记 (豆瓣)
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://img3.doubanio.com/f/shire/420c6a4b676c73bc6af48dfcdd18b662f5c223d7/css/douban.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/shire/ae3f5a3e3085968370b1fc63afcecb22d3284848/css/separation/_all.css" rel="stylesheet" type="text/css"/>
# ...

# %%
url = soup.find('div',id='comments-section').find('span',class_='pl').a['href']

# %%
print(url)
# Out:
# https://movie.douban.com/subject/20495023/comments?status=P

# %%
dom = request.urlopen(url)

# %%
soup = BeautifulSoup(dom, 'html.parser')

# %%
comments = [item.string for item in soup.find_all('p',class_="")[:20]]

# %%
comments
# Out:
# [' 广州试片会。主持人在现场透露：Coco原本涉及到亡灵题材，是不能引进的。但是在过审时，当场看哭了所有广电审查人员，so破例让过了。。。\n        ',
#  ' 供奉的遗像是牵引家人回家的通道，驻留的记忆是保持亡灵存续的神力，热闹的音乐是唤醒思念启封的药引。我为你写了首歌，穿越浩瀚的岁月烟尘，捱过冰冷的孤独冬季，横跨漫长的天人之路，在你老去的时候，唱给你听。这瑰丽的灯火万家，摇曳的烛光千盏，不如你梳着麻花辫坐在床头时，眼里闪烁的星光璀璨。\n        ',
#  ' 邻座的女孩哭倒在我怀里啊电影多么美妙！\n        ',
#  ' 无后同性恋们的一场极大的噩梦。\n        ',
#  ' 我们是人类的一分子，而人类是充满激情的。医学、法律、商业、科技，这些都是崇高的追求，足以支撑人的一生。但音乐、诗歌、梦想、情感，这些才是我们活着的意义。\n        ',
#  ' 11月1日亡灵节当天，墨西哥城的影院里，隔壁座儿的小男孩画着鬼脸儿穿着骷髅服，老奶奶抱着万寿菊，举家一起看coco。生活与动画交叠而映，感慨又感动，炫目又泪目。这才叫文化输出，好羡慕，好嫉妒。（ps：盖尔加西亚~不枉爱了你十余年）（pps：开场前送了20分钟冰雪奇缘番外 ，以为走错片场）\n        ',
#  ' 第一次觉得死后世界通往人间的万寿菊之桥和七夕鹊桥是一样的原理，爱不分种类是共通的，相见是因为想念，存在是因为记忆的力量。而只有墨西哥人能有欢乐的能力把悼念先人的节日过得如此五彩斑斓。欢迎有女儿的爸爸来影院哭一哭。亡灵节海关大厅井井有条，效率极佳!拒绝寂静的死后世界，我们要喧嚣!\n        ',
#  None,
#  ' 皮克斯保持原创的又一巅峰，回忆与遗忘的情感核心，在家庭、音乐、梦想、冒险的故事线下饱满溢出银幕，最后只能以泪洗面。2017年度最佳电影！\n        ',
#  ' 人有三次死亡。第一次是生物学的死亡；第二次是社会宣布你死亡；第三次是最后一个记得你的人离开这个世界。\n想念上个月去世的外婆，想念老爸，想念所有离我而去的人们。\n后悔没带纸，平复了半天情绪最后离开放映厅。。。\n        ',
# ...

# %%
dom = request.urlopen(url)
soup = BeautifulSoup(dom, 'html.parser')

# %%
tmp_url = soup.find('a', class_='next')['href']

# %%
tmp_dom = request.urlopen(url.split('?')[0] + tmp_url)

# %%
tmp_soup = BeautifulSoup(tmp_dom,'html.parser')

# %%
tmp_soup
# Out:
# <!DOCTYPE html>
#
# <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>寻梦环游记 短评</title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification">
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <meta content="寻梦环游记,Coco,影讯,排片,放映时间,电影票价,在线购票" name="keywords">
# <meta content="寻梦环游记短评" name="description">
# <meta content="format=html5; url=http://m.douban.com/movie/subject/20495023/comments" name="mobile-agent">
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# ...

# %%
url.split('?')[0] + tmp_url
# Out:
# 'https://movie.douban.com/subject/20495023/comments?start=20&limit=20&sort=new_score&status=P&percent_type='
