# %%
from urllib import request
from bs4 import BeautifulSoup

# %%
# BeautifulSoup lib note 
url = 'https://movie.douban.com/'
html_page = request.urlopen(url)

# %%
# can try out some other parser such as html.parser, lxml for normal html doc. lxml-xml for parsing html to xml
soup = BeautifulSoup(html_page, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="" lang="zh-cmn-Hans">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
#         豆瓣电影
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <meta content="format=xhtml; url=http://m.douban.com/movie/" http-equiv="mobile-agent"/>
# <meta content="13753521351564752166375" property="qc:admins"/>
# <meta content="电影、经典电影、热映、电视剧、美剧、影评、电影院、电影票、排行、推荐" name="keywords"/>
# <meta content="豆瓣电影提供最新的电影介绍及评论包括上映影片的影讯查询及购票服务。你可以记录想看、在看和看过的电影电视剧，顺便打分、写影评。根据你的口味，豆瓣电影会推荐好电影给你。" name="description"/>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://img3.doubanio.com/f/shire/420c6a4b676c73bc6af48dfcdd18b662f5c223d7/css/douban.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/shire/ae3f5a3e3085968370b1fc63afcecb22d3284848/css/separation/_all.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/movie/8864d3756094f5272d3c93e30ee2e324665855b0/css/movie/base/init.css" rel="stylesheet"/>
# <script type="text/javascript">var _head_start = new Date();</script>
# <script src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/1efae2c2d48b407a9bed76b9dd5dd8de37a8dbe1/js/douban.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js" type="text/javascript"></script>
# <link href="https://img3.doubanio.com/f/movie/8de8dacb3e6a273947b3eaebff52bc9db9a28d4d/css/movie/home.css" rel="stylesheet"/>
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <script>
#         Do.global('https://img3.doubanio.com/f/shire/0e82fba9c90a7daffc62dd2f80b23ff31c5e4739/js/separation/prettyfield.js');
#         Do.global('https://img3.doubanio.com/f/shire/aef14a3cb852be78af0d48b0534beeea33035c0f/js/core/moreurl.js');
#     </script>
# <script type="text/javascript">
#   var _vwo_code = (function() {
#     var account_id = 249272,
#       settings_tolerance = 0,
#       library_tolerance = 2500,
#       use_existing_jquery = false,
#       // DO NOT EDIT BELOW THIS LINE
#       f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());
#
#   +function () {
#     var bindEvent = function (el, type, handler) {
#         var $ = window.jQuery || window.Zepto || window.$
#        if ($ && $.fn && $.fn.on) {
#            $(el).on(type, handler)
#        } else if($ && $.fn && $.fn.bind) {
#            $(el).bind(type, handler)
#        } else if (el.addEventListener){
#          el.addEventListener(type, handler, false);
#        } else if (el.attachEvent){
#          el.attachEvent("on" + type, handler);
#        } else {
#          el["on" + type] = handler;
#        }
#      }
#
#     var _origin_load = _vwo_code.load
#     _vwo_code.load = function () {
#       var args = [].slice.call(arguments)
#       bindEvent(window, 'load', function () {
#         _origin_load.apply(_vwo_code, args)
#       })
#     }
#   }()
#
#   _vwo_settings_timer = _vwo_code.init();
#   </script>
# <style type="text/css"></style>
# <style type="text/css">img { max-width: 100%; }</style>
# <script type="text/javascript"></script>
# <link href="https://img3.doubanio.com/misc/mixed_static/554ab01e9256e005.css" rel="stylesheet"/>
# <link href="https://img3.doubanio.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# </head>
# <body>
# <script type="text/javascript">var _body_start = new Date();</script>
# <link href="//img3.doubanio.com/dae/accounts/resources/321e246/shire/bundle.css" rel="stylesheet" type="text/css"/>
# <div class="global-nav" id="db-global-nav">
# <div class="bd">
# <div class="top-nav-info">
# <a class="nav-login" href="https://www.douban.com/accounts/login?source=movie" rel="nofollow">登录</a>
# <a class="nav-register" href="https://www.douban.com/accounts/register?source=movie" rel="nofollow">注册</a>
# </div>
# <div class="top-nav-doubanapp">
# <a class="lnk-doubanapp" href="https://www.douban.com/doubanapp/app?channel=top-nav">下载豆瓣客户端</a>
# <div class="more-items" id="top-nav-appintro">
# <p class="appintro-title">豆瓣</p>
# <p class="slogan">我们的精神角落</p>
# <p class="qrcode">扫码直接下载</p>
# <div class="download">
# <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=iOS">iPhone</a>
# <span>·</span>
# <a class="download-android" href="https://www.douban.com/doubanapp/redirect?channel=top-nav&amp;direct_dl=1&amp;download=Android">Android</a>
# </div>
# <div id="doubanapp-tip">
# <a class="tip-link" href="https://www.douban.com/doubanapp/app?channel=qipao">豆瓣 5.0 全新发布</a>
# <a class="tip-close" href="javascript: void 0;">×</a>
# </div>
# </div>
# </div>
# <div class="global-nav-items">
# <ul>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-main","uid":"0"}' href="https://www.douban.com" target="_blank">豆瓣</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-book","uid":"0"}' href="https://book.douban.com" target="_blank">读书</a>
# </li>
# <li class="on">
# <a data-moreurl-dict='{"from":"top-nav-click-movie","uid":"0"}' href="https://movie.douban.com">电影</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-music","uid":"0"}' href="https://music.douban.com" target="_blank">音乐</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-location","uid":"0"}' href="https://www.douban.com/location" target="_blank">同城</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-group","uid":"0"}' href="https://www.douban.com/group" target="_blank">小组</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-read","uid":"0"}' href="https://read.douban.com/?dcs=top-nav&amp;dcm=douban" target="_blank">阅读</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-fm","uid":"0"}' href="https://douban.fm/?from_=shire_top_nav" target="_blank">FM</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-time","uid":"0"}' href="https://time.douban.com/?dt_time_source=douban-web_top_nav" target="_blank">时间</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-commodity","uid":"0"}' href="https://dongxi.douban.com/?dcs=top-nav&amp;dcm=douban" target="_blank">东西</a>
# </li>
# <li class="">
# <a data-moreurl-dict='{"from":"top-nav-click-market","uid":"0"}' href="https://market.douban.com/?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank">市集</a>
# </li>
# <li>
# <a class="bn-more" href="#more"><span>更多</span></a>
# <div class="more-items">
# <table cellpadding="0" cellspacing="0">
# <tbody>
# <tr>
# <td>
# <a data-moreurl-dict='{"from":"top-nav-click-ypy","uid":"0"}' href="https://ypy.douban.com" target="_blank">豆瓣摄影</a>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/321e246/shire/bundle.js"></script>
# <link href="//img3.doubanio.com/dae/accounts/resources/321e246/movie/bundle.css" rel="stylesheet" type="text/css"/>
# <div class="nav" id="db-nav-movie">
# <div class="nav-wrap">
# <div class="nav-primary">
# <div class="nav-logo">
# <a href="https://movie.douban.com">豆瓣电影</a>
# </div>
# <div class="nav-search">
# <form action="https://movie.douban.com/subject_search" method="get">
# <fieldset>
# <legend>搜索：</legend>
# <label for="inp-query">
# </label>
# <div class="inp"><input id="inp-query" maxlength="60" name="search_text" placeholder="搜索电影、电视剧、综艺、影人" size="22" value=""/></div>
# <div class="inp-btn"><input type="submit" value="搜索"/></div>
# <input name="cat" type="hidden" value="1002"/>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# <div class="nav-secondary">
# <div class="nav-items">
# <ul>
# <li><a href="https://movie.douban.com/cinema/nowplaying/">影讯&amp;购票</a>
# </li>
# <li><a href="https://movie.douban.com/explore">选电影</a>
# </li>
# <li><a href="https://movie.douban.com/tv/">电视剧</a>
# </li>
# <li><a href="https://movie.douban.com/chart">排行榜</a>
# </li>
# <li><a href="https://movie.douban.com/tag/">分类</a>
# </li>
# <li><a href="https://movie.douban.com/review/best/">影评</a>
# </li>
# <li><a href="https://movie.douban.com/annual2016/?source=navigation">2016年度榜单</a>
# </li>
# <li><a href="https://movie.douban.com/standbyme/2016?source=navigation">2016观影报告</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'movie_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= img}}" width="40" />
#             <p>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 {{if sub_title}}
#                     <br /><span>{{= sub_title}}</span>
#                 {{/if}}
#                 {{if address}}
#                     <br /><span>{{= address}}</span>
#                 {{/if}}
#                 {{if episode}}
#                     {{if episode=="unknow"}}
#                         <br /><span>集数未知</span>
#                     {{else}}
#                         <br /><span>共{{= episode}}集</span>
#                     {{/if}}
#                 {{/if}}
#             </p>
#         </a>
#         </li>
#   </script>
# <script defer="defer" src="//img3.doubanio.com/dae/accounts/resources/321e246/movie/bundle.js"></script>
# <div id="wrapper">
# <div id="content">
# <div class="grid-16-8 clearfix">
# <div id="dale_movie_homepage_top_large"></div>
# <div class="article">
# <div id="dale_movie_home_main_top"></div>
# <script id="db-tmpl-subject-tip" type="text/x-jquery-tmpl">
#         <div id="subject-tip">
#             <div class="subject-tip-hd">
#                 <h3>{{= title}}<span class="release-year">{{= release}}</span></h3>
#                 <p class="star">
#                     <span class="allstar{{= star}}"></span>
#                     {{if star != '00' }}
#                         <span class="subject-rating">{{= parseFloat(rate).toFixed(1)}}</span>
#                     {{/if}}
#                     {{if enough}}
#                         <span class="rater-num">({{= rater}}人评价)</span>
#                     {{/if}}
#                 </p>
#             </div>
#             <div class="subject-tip-bd">
#                 <ul>
#                     <li><span>{{= duration}}</span><span>{{= type}}</span><span>{{= region}}</span></li>
#                     <li class="director"><span class="label">导演</span><span>{{= director}}</span></li>
#                     <li class="actors"><span class="label">主演</span><span>{{= actors}}</span></li>
#                 </ul>
#                 {{if intro}}
#                     <div class="subject-intro">
#                         {{= intro}}
#                     </div>
#                 {{/if}}
#             </div>
#         </div>
#     </script>
# <div class="s" data-dstat-areaid="70" data-dstat-mode="click,expose" id="screening">
# <div class="screening-hd">
# <div class="ui-slide-control">
# <span class="prev-btn"><a class="btn-prev" href="javascript:void(0)"></a></span>
# <span class="next-btn"><a class="btn-next" href="javascript:void(0)"></a></span>
# </div>
# <div class="slide-tip"><span class="ui-slide-index">1</span> / <span class="ui-slide-max">10</span></div>
# <h2>正在热映<span><a href="/cinema/nowplaying/" onclick="moreurl(this, {from:'mv_l_a'})">全部正在热映»</a></span><span><a href="./later/" onclick="moreurl(this, {from:'mv_l_w'})">即将上映»</a></span></h2>
# </div>
# <div class="screening-bd">
# <ul class="ui-slide-content" data-index-max="10" data-slide-index="1">
# <li class="ui-slide-item s" data-actors="本·卫肖 / 休·格兰特 / 休·博内威利" data-director="保罗·金" data-dstat-areaid="70_1" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="103分钟" data-enough="true" data-intro="" data-rate="8.6" data-rater="1422" data-region="英国" data-release="2017" data-star="45" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F343905%3F_v_%3Dyes%26merCode%3D1000011" data-title="帕丁顿熊2 Paddington 2" data-trailer="https://movie.douban.com/subject/26340419/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26340419/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="帕丁顿熊2" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506466229.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26340419/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">帕丁顿熊2</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="rating-star allstar45"></span><span class="subject-rate">8.6</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F343905%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="曼迪·摩尔 / 克莱尔·霍尔特 / 克里斯·J.约翰逊" data-director="约翰内斯·罗伯茨" data-duration="89分钟" data-enough="true" data-intro="" data-rate="6.3" data-rater="6290" data-region="英国" data-release="2016" data-star="35" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F930966%3F_v_%3Dyes%26merCode%3D1000011" data-title="鲨海 47 Meters Down" data-trailer="https://movie.douban.com/subject/26845362/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26845362/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="鲨海" class="" rel="nofollow" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2504892832.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26845362/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">鲨海</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="rating-star allstar35"></span><span class="subject-rate">6.3</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F930966%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="陈学冬 / 张孝全 / 桂纶镁" data-director="彭顺" data-duration="123分钟" data-enough="false" data-intro="" data-rate="" data-rater="670" data-region="中国大陆" data-release="2017" data-star="00" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1203120%3F_v_%3Dyes%26merCode%3D1000011" data-title="巨额来电 猜猜我是誰" data-trailer="https://movie.douban.com/subject/26985857/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26985857/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="巨额来电" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2505456879.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26985857/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">巨额来电</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="text-tip">暂无评分</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1203120%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="林允 / 陈柏霖 / 张云龙" data-director="王郢" data-duration="101分钟" data-enough="false" data-intro="" data-rate="" data-rater="270" data-region="中国大陆" data-release="2017" data-star="00" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1198459%3F_v_%3Dyes%26merCode%3D1000011" data-title="假如王子睡着了" data-trailer="https://movie.douban.com/subject/26336256/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26336256/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="假如王子睡着了" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506825667.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26336256/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">假如王子睡着...</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="text-tip">暂无评分</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1198459%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="安东尼·冈萨雷斯 / 盖尔·加西亚·贝纳尔 / 本杰明·布拉特" data-director="李·昂克里奇" data-duration="105分钟" data-enough="true" data-intro="" data-rate="9.1" data-rater="203370" data-region="美国" data-release="2017" data-star="45" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342068%3F_v_%3Dyes%26merCode%3D1000011" data-title="寻梦环游记 Coco" data-trailer="https://movie.douban.com/subject/20495023/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/20495023/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="寻梦环游记" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2503997609.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/20495023/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">寻梦环游记</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar45"></span><span class="subject-rate">9.1</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342068%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item s" data-actors="道格拉斯·布斯 / 杰罗姆·弗林 / 罗伯特·古拉奇克" data-director="多洛塔·科别拉" data-dstat-areaid="70_2" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="95分钟" data-enough="true" data-intro="" data-rate="8.7" data-rater="6747" data-region="英国" data-release="2017" data-star="45" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F337443%3F_v_%3Dyes%26merCode%3D1000011" data-title="至爱梵高·星空之谜 Loving Vincent" data-trailer="https://movie.douban.com/subject/25837262/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/25837262/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="至爱梵高·星空之谜" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506935748.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/25837262/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">至爱梵高·星...</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="rating-star allstar45"></span><span class="subject-rate">8.7</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F337443%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="乔什·布洛林 / 迈尔斯·特勒 / 杰夫·布里吉斯" data-director="约瑟夫·科辛斯基" data-duration="127分钟(中国大陆)" data-enough="true" data-intro="" data-rate="8.2" data-rater="671" data-region="美国" data-release="2017" data-star="45" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F368228%3F_v_%3Dyes%26merCode%3D1000011" data-title="勇往直前 Only the Brave" data-trailer="https://movie.douban.com/subject/26718828/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26718828/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="勇往直前" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p
https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2504027804.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/2158490/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">正义联盟</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar35"></span><span class="subject-rate">6.7</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F341195%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="杰弗里·迪恩·摩根 / 罗伯特·德尼罗 / 凯特·波茨沃斯" data-director="斯科特·曼" data-duration="92分钟(中国大陆)" data-enough="true" data-intro="" data-rate="6.3" data-rater="2950" data-region="美国" data-release="2015" data-star="35" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F336946%3F_v_%3Dyes%26merCode%3D1000011" data-title="双面劫匪 Heist" data-trailer="https://movie.douban.com/subject/25889465/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/25889465/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="双面劫匪" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2507024038.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/25889465/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">双面劫匪</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="rating-star allstar35"></span><span class="subject-rate">6.3</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F336946%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item s" data-actors="" data-director="艾辛" data-dstat-areaid="70_3" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="99分钟" data-enough="false" data-intro="" data-rate="" data-rater="13" data-region="中国大陆" data-release="2017" data-star="00" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1211089%3F_v_%3Dyes%26merCode%3D1000011" data-title="北平以北" data-trailer="https://movie.douban.com/subject/27180871/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/27180871/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="北平以北" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506935277.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/27180871/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">北平以北</a>
# <span class="new-show"></span>
# </li>
# <li class="rating">
# <span class="text-tip">暂无评分</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1211089%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2504455660.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26930504/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">烟花</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar30"></span><span class="subject-rate">5.3</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1198813%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="罗翔 / 李佳颖 / 江兰萱" data-director="邓安东" data-duration="96分钟" data-enough="false" data-intro="" data-rate="" data-rater="182" data-region="中国大陆" data-release="2017" data-star="00" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1208145%3F_v_%3Dyes%26merCode%3D1000011" data-title="笔仙咒怨" data-trailer="https://movie.douban.com/subject/27054612/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/27054612/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="笔仙咒怨" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506139427.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/27054612/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">笔仙咒怨</a>
# </li>
# <li class="rating">
# <span class="text-tip">暂无评分</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1208145%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item s" data-actors="本·卫肖 / 妮可·基德曼 / 休·博内威利" data-director="保罗·金" data-dstat-areaid="70_4" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="95分钟" data-enough="true" data-intro="" data-rate="7.6" data-rater="103823" data-region="英国" data-release="2014" data-star="40" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F78827%3F_v_%3Dyes%26merCode%3D1000011" data-title="帕丁顿熊 Paddington" data-trailer="https://movie.douban.com/subject/2998373/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/2998373/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="帕丁顿熊" class="" rel="nofollow" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2231740424.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/2998373/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">帕丁顿熊</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar40"></span><span class="subject-rate">7.6</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F78827%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="郑恺 / 张雨绮 / 谢依霖" data-director="王晶" data-duration="91分钟" data-enough="true" data-intro="" data-rate="3.1" data-rater="3970" data-region="中国大陆" data-release="2017" data-star="15" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F246019%3F_v_%3Dyes%26merCode%3D1000011" data-title="降魔传" data-trailer="https://movie.douban.com/subject/22557335/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/22557335/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="降魔传" class="" rel="nofollow" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2503850915.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/22557335/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">降魔传</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar15"></span><span class="subject-rate">3.1</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F246019%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="张晋 / 余文乐 / 文咏珊" data-director="李子俊" data-duration="100分钟" data-enough="true" data-intro="" data-rate="5.1" data-rater="3058" data-region="香港" data-release="2017" data-star="25" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F558332%3F_v_%3Dyes%26merCode%3D1000011" data-title="狂兽 狂獸" data-trailer="https://movie.douban.com/subject/26747274/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26747274/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="狂兽" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2502374737.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26747274/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">狂兽</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar25"></span><span class="subject-rate">5.1</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F558332%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="肯尼思·布拉纳 / 佩内洛普·克鲁兹 / 威廉·达福" data-director="肯尼思·布拉纳" data-duration="114分钟" data-enough="true" data-intro="" data-rate="7.0" data-rater="90977" data-region="美国" data-release="2017" data-star="35" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F344422%3F_v_%3Dyes%26merCode%3D1000011" data-title="东方快车谋杀案 Murder on the Orient Express" data-trailer="https://movie.douban.com/subject/25790761/trailer">
://img1.doubanio.com/view/photo/s_ratio_poster/public/p2504997087.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/1297574/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">英雄本色</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar45"></span><span class="subject-rate">8.7</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F313%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="段奕宏 / 余男 / 王景春" data-director="常征" data-duration="105分钟" data-enough="true" data-intro="" data-rate="6.6" data-rater="7959" data-region="中国大陆" data-release="2017" data-star="35" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1196171%3F_v_%3Dyes%26merCode%3D1000011" data-title="引爆者" data-trailer="https://movie.douban.com/subject/26897427/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26897427/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="引爆者" class="" rel="nofollow" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2503578746.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26897427/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">引爆者</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar35"></span><span class="subject-rate">6.6</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F1196171%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="刘亦菲 / 埃米尔·赫斯基 / 李芳淙" data-director="比利·奥古斯特" data-duration="97分钟" data-enough="true" data-intro="" data-rate="6.1" data-rater="5108" data-region="中国大陆" data-release="2017" data-star="30" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F343985%3F_v_%3Dyes%26merCode%3D1000011" data-title="烽火芳菲" data-trailer="https://movie.douban.com/subject/25865831/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/25865831/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="烽火芳菲" class="" rel="nofollow" src="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p2504885106.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/25865831/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">烽火芳菲</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar30"></span><span class="subject-rate">6.1</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F343985%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item s" data-actors="周渝民 / 薛凯琪 / 郑中基" data-director="谷德昭" data-dstat-areaid="70_6" data-dstat-mode="click,expose" data-dstat-viewport=".screening-bd" data-dstat-watch=".ui-slide-content" data-duration="99分钟" data-enough="true" data-intro="" data-rate="4.7" data-rater="1004" data-region="中国大陆" data-release="2017" data-star="25" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342193%3F_v_%3Dyes%26merCode%3D1000011" data-title="天生不对" data-trailer="https://movie.douban.com/subject/26696871/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26696871/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="天生不对" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2503848298.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26696871/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">天生不对</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar25"></span><span class="subject-rate">4.7</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342193%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# </li><li class="ui-slide-item" data-actors="郭德纲 / 于谦 / 岳云鹏" data-director="张鹤栾" data-duration="92分钟" data-enough="true" data-intro="" data-rate="2.8" data-rater="1332" data-region="中国大陆" data-release="2017" data-star="15" data-ticket="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342362%3F_v_%3Dyes%26merCode%3D1000011" data-title="相声大电影之我要幸福" data-trailer="https://movie.douban.com/subject/26811605/trailer">
# <ul class="">
# <li class="poster">
# <a href="https://movie.douban.com/subject/26811605/?from=showing" onclick="moreurl(this, {from:'mv_a_pst'})">
# <img alt="相声大电影之我要幸福" class="" rel="nofollow" src="https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2506165789.jpg"/>
# </a>
# </li>
# <li class="title">
# <a class="" href="https://movie.douban.com/subject/26811605/?from=showing" onclick="moreurl(this, {from:'mv_a_tl'})">相声大电影之...</a>
# </li>
# <li class="rating">
# <span class="rating-star allstar15"></span><span class="subject-rate">2.8</span>
# </li>
# <li class="ticket_btn"><span><a href="https://movie.douban.com/ticket/redirect/?url=https%3A%2F%2Fm.maoyan.com%2Fcinema%2Fmovie%2F342362%3F_v_%3Dyes%26merCode%3D1000011" onclick="moreurl(this, {from:'mv_b_tc'})" target="_blank">选座购票</a></span></li>
# </ul>
# ...
# <div class="review-meta">
# <a href="https://www.douban.com/people/2548235/">小雨沙沙</a> 评论
#                 <a href="https://movie.douban.com/subject/26830891/?from=reviews">《极光之恋》</a>
# <span class="allstar40"></span>
# </div>
# <div class="review-content">
#                 都挺卡司，其实相当不错啊，马可关晓彤暂时不说，温太医好歹是中戏老师出身，演一部火一部的那种，这次后期可能还有很大一part黑化戏份，跟前期温文尔雅的样子不一样，感觉会很有看点。 赵韩樱子好像也是第一次演...
#                     <a href="https://movie.douban.com/review/8968479/">(全文)</a>
# </div>
# </div>
# </div>
# <div class="review ">
# <div class="review-hd">
# <a href="https://movie.douban.com/subject/26897427/?from=reviews">
# <img alt="引爆者" class="lazy" data-original="https://img3.doubanio.com/view/photo/s_ratio_poster/public/p
a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="aside">
# <div class="rating_answer">
# <ul>
# <li>
# <a href="https://blog.douban.com/douban/2015/12/18/3060/" target="_blank">豆瓣电影评分八问</a>
# </li>
# </ul>
# </div>
# <!-- douban ad begin -->
# <div id="dale_movie_home_side_top"></div>
# <div class="s" data-dstat-areaid="71" data-dstat-mode="click,expose" id="dale_movie_home_top_right"></div>
# <!-- douban ad end -->
# <div class="hot_link">
# <h2> 电影活动  · · · · · · </h2>
# <ul>
# <li>
# <a data-bid="2531" href="https://www.douban.com/note/647968989/" target="_blank">
#                   一周大新闻丨传迪士尼600亿收购福斯
#               </a>
# </li>
# <li>
# <a data-bid="2532" href="https://www.douban.com/note/647995846/" target="_blank">
#                   韩庚狠甩偶像包袱，自封谐星里的美男子
#               </a>
# </li>
# <li>
# <a data-bid="2530" href="https://www.douban.com/note/647706635/" target="_blank">
#                   艺术从业者眼中的梵高与《至爱梵高》
#               </a>
# </li>
# </ul>
# </div>
# <!-- douban ad begin -->
# <div class="s" data-dstat-areaid="71" data-dstat-mode="click,expose" id="dale_movie_home_top_right_ford"></div>
# <div class="s" data-dstat-areaid="71" data-dstat-mode="click,expose" id="dale_movie_home_top_right2"></div>
# <!-- douban ad end -->
# <div class="s" data-dstat-areaid="75" data-dstat-mode="click,expose" id="billboard">
# <div class="billboard-hd">
# <h2>本周口碑榜<span><a href="/chart">更多榜单»</a></span></h2>
# </div>
# <div class="billboard-bd">
# <table>
# <tr>
# <td class="order">1</td>
# <td class="title"><a href="https://movie.douban.com/subject/20495023/" onclick="moreurl(this, {from:'mv_rk'})">寻梦环游记</a></td>
# </tr>
# <tr>
# <td class="order">2</td>
# <td class="title"><a href="https://movie.douban.com/subject/26761416/" onclick="moreurl(this, {from:'mv_rk'})">至暗时刻</a></td>
# </tr>
# <tr>
# <td class="order">3</td>
# <td class="title"><a href="https://movie.douban.com/subject/26420808/" onclick="moreurl(this, {from:'mv_rk'})">绿地黄花</a></td>
# </tr>
# <tr>
# <td class="order">4</td>
# <td class="title"><a href="https://movie.douban.com/subject/26884826/" onclick="moreurl(this, {from:'mv_rk'})">日常对话</a></td>
# </tr>
# <tr>
# <td class="order">5</td>
# <td class="title"><a href="https://movie.douban.com/subject/27094896/" onclick="moreurl(this, {from:'mv_rk'})">方法派</a></td>
# </tr>
# <tr>
# <td class="order">6</td>
# <td class="title"><a href="https://movie.douban.com/subject/26754095/" onclick="moreurl(this, {from:'mv_rk'})">火车司机日记</a></td>
# </tr>
# <tr>
# <td class="order">7</td>
# <td class="title"><a href="https://movie.douban.com/subject/26678784/" onclick="moreurl(this, {from:'mv_rk'})">夺金四贱客</a></td>
# </tr>
# <tr>
# <td class="order">8</td>
# <td class="title"><a href="https://movie.douban.com/subject/26833865/" onclick="moreurl(this, {from:'mv_rk'})">真白之恋</a></td>
# </tr>
# <tr>
# <td class="order">9</td>
# <td class="title"><a href="https://movie.douban.com/subject/26732377/" onclick="moreurl(this, {from:'mv_rk'})">川流之岛</a></td>
# </tr>
# <tr>
# <td class="order">10</td>
# <td class="title"><a href="https://movie.douban.com/subject/26755367/" onclick="moreurl(this, {from:'mv_rk'})">泥土之界</a></td>
# </tr>
# </table>
# </div>
# </div>
# <!-- douban ad begin -->
# <div id="dale_movie_home_bottom_right"></div>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about?policy=disclaimer">免责声明</a>
#
#     · <a href="https://help.douban.com/?app=movie" target="_blank">帮助中心</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
# </div>
# </div>
# <script src="https://img3.doubanio.com/misc/mixed_static/7a7f0bc411c19e8c.js" type="text/javascript"></script>
# <link href="https://img3.doubanio.com/f/shire/8377b9498330a2e6f056d863987cc7a37eb4d486/css/ui/dialog.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/movie/1d829b8605b9e81435b127cbf3d16563aaa51838/css/movie/mod/reg_login_pop.css" rel="stylesheet" type="text/css"/>
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/4ea3216519a6183c7bcd4f7d1a6d4fd57ce1a244/js/ui/dialog.js" type="text/javascript"></script>
# <script type="text/javascript">
#         var HTTPS_DB='https://www.douban.com';
# var account_pop={open:function(o,e){e?referrer="?referrer="+encodeURIComponent(e):referrer="?referrer="+window.location.href;var n="",i="",t=382;"reg"===o?(n="用户注册",i="https://accounts.douban.com/popup/login?source=movie#popup_register",t=480):"login"===o&&(n="用户登录",i="https://accounts.douban.com/popup/login?source=movie");var r=document.location.protocol+"//"+document.location.hostname,a=dui.Dialog({width:478,title:n,height:t,cls:"account_pop",isHideTitle:!0,modal:!0,content:"<iframe scrolling='no' frameborder='0' width='478' height='"+t+"' src='"+i+"' name='"+r+"'></iframe>"},!0),c=a.node;if(c.undelegate(),c.delegate(".dui-dialog-close","click",function(){var o=$("body");o.find("#login_msk").hide(),o.find(".account_pop").remove()}),$(window).width()<478){var u="";"reg"===o?u=HTTPS_DB+"/accounts/register"+referrer:"login"===o&&(u=HTTPS_DB+"/accounts/login"+referrer),window.location.href=u}else a.open();$(window).bind("message",function(o){"https://accounts.douban.com"===o.originalEvent.origin&&(c.find("iframe").css("height",o.originalEvent.data),c.height(o.originalEvent.data),a.update())})}};Douban&&Douban.init_show_login&&(Douban.init_show_login=function(o){var e=$(o);e.click(function(){var o=e.data("ref")||"";return account_pop.open("login",o),!1})}),Do(function(){$("body").delegate(".pop_register","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("reg",e),!1}),$("body").delegate(".pop_login","click",function(o){o.preventDefault();var e=$(this).data("ref")||"";return account_pop.open("login",e),!1})});
#     </script>
# <!-- douban ad begin -->
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'lzx8NStkaa8',
#             criteria = '3:/',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_movie_homepage_top_large', 'dale_movie_home_top_right', 'dale_movie_home_top_right_ford', 'dale_movie_home_top_right2', 'dale_movie_home_side_top', 'dale_movie_home_main_top', 'dale_movie_home_bottom_right', 'dale_movie_homepage_bottom', 'movie_home_left_bottom', 'dale_movie_home_bottom_right_down', 'dale_movie_home_inner_bottom', 'dale_movie_home_download_bottom'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', 'https://img3.doubanio.com/f/adjs/5a274edd066a1fca36439233b6aa5f8ebce75685/ad.release.js');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
# <!-- douban ad end -->
# <script type="text/javascript">
# var _paq = _paq || [];
# _paq.push(['trackPageView']);
# _paq.push(['enableLinkTracking']);
# (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://img3.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
# })();
# </script>
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-19', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id]);
#       _gaq.push([method('_setSampleRate'), '5']);
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
# <!-- sindar17c-docker-->
# <script>_SPLITTEST=''</script>
# </body>
# </html>

# %%
# four kinds of object in bs: tag, navigablestring, BeautifulSoup and Comment
tag = soup.a
tag
# Out:
# <a class="nav-login" href="https://www.douban.com/accounts/login?source=movie" rel="nofollow">登录</a>

# %%
# each attribute has a name which could also be modified
print(tag.name)
tag.name = "p"
print(tag)
# Out:
# a
# <p class="nav-login" href="https://www.douban.com/accounts/login?source=movie" rel="nofollow">登录</p>

# %%
# accessing the attributes
tag['class']
# Out:
# ['nav-login']

# %%
# get the attributes as a dictionary which also means you can modify the attributes the way you modify a dictionary 
tag.attrs
# Out:
# {'class': ['nav-login'],
#  'href': 'https://www.douban.com/accounts/login?source=movie',
#  'rel': ['nofollow']}

# %%
del tag['rel']
tag.attrs
# Out:
# {'class': ['nav-login'],
#  'href': 'https://www.douban.com/accounts/login?source=movie'}

# %%
# NavigableString: basically, it is the content inside the tag 
print(tag.string)
type(tag.string)
# Out:
# 登录
# bs4.element.NavigableString

# %%
# modification
tag.string.replace_with("Log in")
tag
# Out:
# <p class="nav-login" href="https://www.douban.com/accounts/login?source=movie">Log in</p>

# %%
# BeautifulSoup
soup.name
# Out:
# '[document]'

# %%
# navigating a tree: note that these operation could be done in the types described above
soup.head
# Out:
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="webkit" name="renderer"/>
# <meta content="always" name="referrer"/>
# <title>
#         豆瓣电影
# </title>
# <meta content="cZdR4xxR7RxmM4zE" name="baidu-site-verification"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Sun, 6 Mar 2005 01:00:00 GMT" http-equiv="Expires"/>
# <meta content="format=xhtml; url=http://m.douban.com/movie/" http-equiv="mobile-agent"/>
# <meta content="13753521351564752166375" property="qc:admins"/>
# <meta content="电影、经典电影、热映、电视剧、美剧、影评、电影院、电影票、排行、推荐" name="keywords"/>
# <meta content="豆瓣电影提供最新的电影介绍及评论包括上映影片的影讯查询及购票服务。你可以记录想看、在看和看过的电影电视剧，顺便打分、写影评。根据你的口味，豆瓣电影会推荐好电影给你。" name="description"/>
# <link href="https://img3.doubanio.com/f/movie/d59b2715fdea4968a450ee5f6c95c7d7a2030065/pics/movie/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="https://img3.doubanio.com/f/shire/420c6a4b676c73bc6af48dfcdd18b662f5c223d7/css/douban.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/shire/ae3f5a3e3085968370b1fc63afcecb22d3284848/css/separation/_all.css" rel="stylesheet" type="text/css"/>
# <link href="https://img3.doubanio.com/f/movie/8864d3756094f5272d3c93e30ee2e324665855b0/css/movie/base/init.css" rel="stylesheet"/>
# <script type="text/javascript">var _head_start = new Date();</script>
# <script src="https://img3.doubanio.com/f/movie/0495cb173e298c28593766009c7b0a953246c5b5/js/movie/lib/jquery.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/1efae2c2d48b407a9bed76b9dd5dd8de37a8dbe1/js/douban.js" type="text/javascript"></script>
# <script src="https://img3.doubanio.com/f/shire/0efdc63b77f895eaf85281fb0e44d435c6239a3f/js/separation/_all.js" type="text/javascript"></script>
# <link href="https://img3.doubanio.com/f/movie/8de8dacb3e6a273947b3eaebff52bc9db9a28d4d/css/movie/home.css" rel="stylesheet"/>
# <script data-cfg-autoload="false" src="https://img3.doubanio.com/f/shire/77323ae72a612bba8b65f845491513ff3329b1bb/js/do.js" type="text/javascript"></script>
# <script>
#         Do.global('https://img3.doubanio.com/f/shire/0e82fba9c90a7daffc62dd2f80b23ff31c5e4739/js/separation/prettyfield.js');
#         Do.global('https://img3.doubanio.com/f/shire/aef14a3cb852be78af0d48b0534beeea33035c0f/js/core/moreurl.js');
#     </script>
# <script type="text/javascript">
#   var _vwo_code = (function() {
#     var account_id = 249272,
#       settings_tolerance = 0,
#       library_tolerance = 2500,
#       use_existing_jquery = false,
#       // DO NOT EDIT BELOW THIS LINE
#       f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());
#
#   +function () {
#     var bindEvent = function (el, type, handler) {
#         var $ = window.jQuery || window.Zepto || window.$
#        if ($ && $.fn && $.fn.on) {
#            $(el).on(type, handler)
#        } else if($ && $.fn && $.fn.bind) {
#            $(el).bind(type, handler)
#        } else if (el.addEventListener){
#          el.addEventListener(type, handler, false);
#        } else if (el.attachEvent){
#          el.attachEvent("on" + type, handler);
#        } else {
#          el["on" + type] = handler;
#        }
#      }
#
#     var _origin_load = _vwo_code.load
#     _vwo_code.load = function () {
#       var args = [].slice.call(arguments)
#       bindEvent(window, 'load', function () {
#         _origin_load.apply(_vwo_code, args)
#       })
#     }
#   }()
#
#   _vwo_settings_timer = _vwo_code.init();
#   </script>
# <style type="text/css"></style>
# <style type="text/css">img { max-width: 100%; }</style>
# <script type="text/javascript"></script>
# <link href="https://img3.doubanio.com/misc/mixed_static/554ab01e9256e005.css" rel="stylesheet"/>
# <link href="https://img3.doubanio.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# </head>

# %%
soup.title
# Out:
# <title>
#         豆瓣电影
# </title>
